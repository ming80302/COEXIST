# %% [markdown]
# Reproduce the sst anomaly maps for each WT

# %%
import datetime
import numpy as np
import pandas as pd
from pandas.tseries.offsets import MonthEnd
import xarray as xr
import matplotlib.pyplot as plt
import glob 
import os.path
import cartopy 
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# casper_2020

# %%
level_s = np.array([0, 1, 2.5, 5, 7.5, 10, 15, 20,25, 37.5, 50,
         75, 100, 125, 150, 200, 250, 300, 400, 500, 600, 750])

proj = ccrs.PlateCarree()

def ax_coastlines_country(ax_s):
    ax_s.coastlines(linewidths=0.5)
    ax_s.add_feature(cfeature.NaturalEarthFeature(category='cultural',
                                           name='admin_0_countries',
                                           scale='10m',
                                           facecolor='none',
                                           edgecolor='black',
                                           linewidth=0.2))
 
def plot_prec_12(prec, min_v, max_v, n_lev, cmap_s, colorbar_ori, title_s):
    '''
    prec(12,nlat, nlon): 3d variable to plot
    colorbar_ori: colorbar orientation, verticle or horizontal
    title_s: the common title for subplot
    '''
    fig = plt.figure(figsize=(20,10))
    
    cnlevel = np.linspace(min_v, max_v, num=n_lev)
  
    for col in range(12):
        ax_s = plt.subplot(4, 3, col+1, projection=proj)
        ax_coastlines_country(ax_s)
        ax_s.add_feature(cfeature.STATES, linestyle=':')
        #ax_s.add_feature(cartopy.feature.OCEAN,zorder=100, edgecolor='k')
 
        mem = col + 1

        im=prec[col].plot.contourf(
            levels=cnlevel,
            cmap=cmap_s,
            vcenter=0,
            ax=ax_s,
            transform=proj,
            add_colorbar=False)
        
        plt.title('WT' + str(mem),fontweight="bold", size=15)

    # single title for All the Subplot
    fig.suptitle('member: ' + title_s, fontweight="bold", fontsize=30)
    
    fig.tight_layout()
    # The position of the bottom edge of the subplots, as a fraction of the figure height.
    #fig.subplots_adjust(bottom=0.15)

    #rect [left, bottom, width, height]
    #cbar_ax = fig.add_axes([0.2, 0.1, 0.7, 0.03])
    #fig.colorbar(im, cax=cbar_ax,orientation='horizontal')
    if colorbar_ori=="vertical":
        #rect [left, bottom, width, height]
        cbar_ax = fig.add_axes([0.99, 0.1, 0.04, 0.8])
    else:
        #rect [left, bottom, width, height]
        cbar_ax = fig.add_axes([0.2, 0.001, 0.7, 0.03])
    
    fig.colorbar(im, cax=cbar_ax, orientation=colorbar_ori)

# %%
dir_ecmwf = '/glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/'
dir_wt = '/glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/'

# %% [markdown]
# ### check on data

# %%
flnm_test = dir_ecmwf + 'sst_199301.grib'
ds = xr.load_dataset(flnm_test, engine="cfgrib");
print('original ', flnm_test)
print(ds.dims)
 
n_mem  = ds.dims['number']
n_fcst = ds.dims['step']
n_lat  = ds.dims['latitude']
n_lon  = ds.dims['longitude']
# Out:
# Ignoring index file '/glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199301.grib.923a8.idx' older than GRIB file
# original  /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199301.grib
# Frozen({'number': 25, 'step': 215, 'latitude': 101, 'longitude': 360})

# %% [markdown]
# #### climatology

# %%
### calculate 215-day climatology of member 1-25

year_s = 1993
year_e = 2021
#year_s = year_e
flnm_o = dir_ecmwf + 'sst_clim_215day.nc'

if os.path.isfile(flnm_o):
    print(flnm_o, 'exist')
    print('z500 mean of member 1-25 ')
    with  xr.open_dataset(flnm_o) as ds:
        z500 = ds.sst      
        print(ds.dims)
else:
    is_first = True    
    for year in range(year_s, year_e+1, 1):
        print(year)
        for month in range(1,12+1,1):
            mon_s = str(month).zfill(2)
             
            flnm = dir_ecmwf + 'sst_' + str(year) + mon_s + '.grib' 
            print(flnm)
            ds = xr.load_dataset(flnm, engine="cfgrib")
            # read 1-25 members , member 26-51 starts 2017 
            z500 = ds.sst[:25].squeeze(drop=True).mean(dim=['number','step']) 
            if is_first == True:
                data_all = z500 
                is_first = False
            else:
                data_all = xr.concat([data_all, z500], dim='step')
                                         
    print(data_all.shape)
    z500_mean = data_all.mean(dim='step')
    z500_mean = z500_mean.rename('sst')  
     
    print(flnm_o) 
    z500_mean.to_netcdf(path = flnm_o)
# Out:
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_clim_215day.nc exist
# z500 mean of member 1-25
# Frozen({'latitude': 101, 'longitude': 360})

# %% [markdown]
# #### break 1-51 member data to each member
# (to speed up process)

# %%
year_s = 1993
year_e = 2021

#year_s = 2017

for year in range(year_s, year_e+1, 1):
    print(year)
    for month in range(1,12+1,1):
        mon_s = str(month).zfill(2)
        flnm_i = dir_ecmwf + 'sst_' + str(year) + mon_s + '.grib' 
        # print(flnm_i)
        flnm_o = dir_ecmwf + 'sst_' + str(year) + mon_s + '_mem01.nc' 
        if os.path.isfile(flnm_o):
            print(flnm_o, ' - member 25 (-2016) or 51 (2017-) exist')
        else:
            if year < 2017:
                n_mem = 25
            else:
                n_mem = 51
        
            ds = xr.load_dataset(flnm_i, engine="cfgrib") 
        
            z500 = ds.sst
            
            for mem  in range(1, n_mem+1, 1):  
                mem_s = str(mem).zfill(2)
                flnm_o = dir_ecmwf + 'sst_' + str(year) + mon_s + '_mem' + mem_s +'.nc' 
                #print(flnm_o)
                z500_12Z = z500[mem-1,:,:,:]
                z500_12Z = z500_12Z.rename('sst')
                z500_12Z = z500_12Z.rename({'step':'forecast_time'})
                z500_12Z.to_netcdf(path = flnm_o)
# Out:
# 1993
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199301_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199302_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199303_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199304_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199305_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199306_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199307_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199308_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199309_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199310_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199311_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199312_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# 1994
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199401_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199402_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199403_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199404_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199405_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199406_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199407_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199408_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199409_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199410_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199411_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199412_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# 1995
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199501_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199502_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199503_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199504_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199505_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199506_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199507_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199508_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199509_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199510_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199511_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199512_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# 1996
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199601_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199602_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199603_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199604_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199605_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199606_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199607_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199608_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199609_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199610_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199611_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199612_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# 1997
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199701_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199702_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199703_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199704_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199705_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199706_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199707_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199708_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199709_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199710_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199711_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199712_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# 1998
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199801_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199802_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199803_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199804_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199805_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199806_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199807_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199808_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199809_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199810_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199811_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199812_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# 1999
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199901_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199902_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199903_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199904_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199905_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199906_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199907_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199908_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_199909_mem01.nc  - member 25 (-2016) or 51 (2017-) exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/sst/sst_
for mem in range(1, n_mem+1, 1): 
    mem_s = str(mem).zfill(2) 
    flnm_o = dir_wt + 'sst_ano_mem' + mem_s +'.nc'

    if os.path.isfile(flnm_o):
        print(flnm_o, 'exist')
    else:
        for nw in range(n_wt):
            print('mem', mem, nw+1)
            is_first = True
            if mem < 26:
                year_s = 1993
            else:
                year_s = 2017
            
            for year in range(year_s, year_e+1, 1):   
                for month in range(1, 13, 1):
                    month_s = str(month).zfill(2)

                    # read WT file
                    flnm_wt = dir_wt + 'CONUS-WTs_' + str(year) + month_s + '_'+ mem_s +'.cla'               
                    wts = pd.read_csv(flnm_wt, delimiter = '\t', header=None,  names=["year", "month", "day", "wt"])
           
                    if nw+1 in wts.wt.unique(): 
                        wts_g = wts.groupby(['wt'])
                        flnm = dir_ecmwf + 'sst_' + str(year) + month_s + '_mem' + mem_s + '.nc'  
                        
                        with  xr.open_dataset(flnm) as ds:
                            z500 = ds.sst
                            g_ind = wts_g.get_group(nw+1).index     
                         
                            z500_wt = z500[g_ind,:,:]                     
                   
                            if is_first == True:
                                data_all = z500_wt.copy()
                                is_first = False
                            else:
                                data_all = xr.concat([data_all, z500_wt.copy()], dim='forecast_time')                                
               
            z500_3d[nw] = (data_all.mean("forecast_time") - z500_cli)/z500_cli  
     
        z500_xr = xr.DataArray(z500_3d, 
                coords={'latitude': z500_cli.latitude, 'longitude': z500_cli.longitude, 'wt':range(n_wt)},
                dims=["wt", "latitude", "longitude"])
        print(flnm_o)
        z500_xr.to_netcdf(path = flnm_o)
# Out:
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem01.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem02.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem03.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem04.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem05.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem06.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem07.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem08.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem09.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem10.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem11.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem12.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem13.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem14.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem15.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem16.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem17.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem18.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem19.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem20.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem21.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem22.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem23.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem24.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem25.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem26.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem27.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem28.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem29.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem30.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem31.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem32.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem33.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem34.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem35.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem36.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem37.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem38.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem39.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem40.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem41.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem42.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem43.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem44.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem45.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem46.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem47.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem48.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem49.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem50.nc exist
# /glade/campaign/mmm/c3we/mingge/COEXIST/ECMWF/WT_01/sst_ano_mem51.nc exist

# %% [markdown]
# #### ensemble average z500 anomaly maps for each WT
#
# https://www.frontiersin.org/articles/10.3389/fenvs.2019.00036/full

# %%
flnm_cli = dir_ecmwf + 'sst_clim_215day.nc'
with  xr.open_dataset(flnm_cli) as ds_cli:
    z500_cli = ds_cli.sst

n_lat = z500_cli.shape[0]
n_lon = z500_cli.shape[1]
n_mem = 51
for mem in range(1, n_mem+1,1):
    mem_s = str(mem).zfill(2)
    flnm_wt = dir_wt + 'sst_ano_mem' + mem_s + '.nc'
    #print(flnm_wt)
    
    with  xr.open_dataset(flnm_wt) as ds:
        z500_wt = ds.__xarray_dataarray_variable__
        if mem == 1:
            z500_avg = z500_wt.copy()
        else:
            z500_avg = z500_avg + z500_wt

plot_prec_12(z500_avg*100/n_mem, -4., 4., 17, 'coolwarm', 'horizontal', 'ensemble average')
